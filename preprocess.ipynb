# %% [markdown]
# ## LIBS

# %%
import pandas as pd
import os
import numpy as np
import yaml
import re
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from category_encoders import CatBoostEncoder
import lazypredict
from lazypredict.Supervised import LazyRegressor
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import all_estimators
from sklearn.base import RegressorMixin
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from yellowbrick.regressor import ResidualsPlot

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
#random seed
random.seed(42)
config_path = os.path.join(os.getcwd(), 'config\config.yaml')

# %%
with open(config_path) as f:
    config = yaml.safe_load(f)

# %%
df = pd.read_csv(os.path.join(config['SavePath'], config['files'] + ".csv"))
df.shape
# Out:
# (12513, 52)

# %% [markdown]
# ## TARGET VARIABLE

# %%
def convert_to_euro(price):
    price = price.replace("\u2009", "").replace("\t", "").replace(",", "")
    if pd.isnull(price):
        return np.nan
    if price.startswith("About"):
        if "INR" in price:
            price = float(price.split(" ")[1]) * config['conversion_rates']['INR']
        else:
            price = float(price.split(" ")[1]) + round(random.uniform(0, 9), 2)
    else:
        euro_tag = [p for p in price.split("/") if "€" in p]
        if len(euro_tag) > 0:
            price = float(euro_tag[0].split("€")[1])
        else:
            currency_tag = []
            for c in config['conversion_rates'].keys():
                if c in price:
                    currency_tag.append(c)
            if currency_tag:
                number = float(re.findall("\d+", price.split(currency_tag[0])[1])[0])
                price = config['conversion_rates'][currency_tag[0]] * number 
    return price

# %%
round(random.uniform(0, 9), 2)
# Out:
# 5.75

# %%
df['MISC_Price'].isnull().sum(), df.shape
# Out:
# (4074, (12513, 52))

# %%
df.loc[df['MISC_Price'].str.contains('BTC', na=False), 'MISC_Price'] = np.nan
# df = df.dropna(subset=['MISC_Price'])
# df = df.reset_index(drop=True)
df.shape
# Out:
# (12513, 52)

# %%
df_na = df[df['MISC_Price'].isna()]
df = df.dropna(subset=['MISC_Price'])
df.shape
# Out:
# (8438, 52)

# %%
df['MISC_Price_Euro'] = df['MISC_Price'].apply(convert_to_euro)

# %%
df[['Name','MISC_Price', 'MISC_Price_Euro']].head(10)
# Out:
#                          Name     MISC_Price  MISC_Price_Euro
# 0      Acer Chromebook Tab 10  About 330 EUR           330.23
# 1          Acer Iconia Talk S  About 170 EUR           172.48
# 2         Acer Liquid Z6 Plus  About 250 EUR           252.01
# 3              Acer Liquid Z6  About 120 EUR           126.63
# 4   Acer Iconia Tab 10 A3-A40  About 230 EUR           236.09
# 5              Acer Liquid X2  About 230 EUR           238.03
# 7       Acer Liquid Zest Plus  About 200 EUR           200.78
# 8            Acer Liquid Zest  About 110 EUR           113.80
# 9             Acer Predator 8  About 350 EUR           350.27
# 10     Acer Liquid Jade Primo  About 220 EUR           221.97

# %% [markdown]
# ## Other variables

# %%
df.info(
    null_counts=True
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8438 entries, 0 to 12494
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  8438 non-null   object
#  1   url                    8438 non-null   object
#  2   imgUrl                 8438 non-null   object
#  3   Name                   8438 non-null   object
#  4   NETWORK_Technology     8438 non-null   object
#  5   NETWORK_2G_bands       8438 non-null   object
#  6   NETWORK_3G_bands       6874 non-null   object
#  7   NETWORK_4G_bands       4609 non-null   object
#  8   NETWORK_5G_bands       1045 non-null   object
#  9   NETWORK_GPRS           1837 non-null   object
#  10  NETWORK_EDGE           1829 non-null   object
#  11  NETWORK_Speed          6843 non-null   object
#  12  LAUNCH_Announced       8436 non-null   object
#  13  LAUNCH_Status          8438 non-null   object
#  14  BODY_Dimensions        8434 non-null   object
#  15  BODY_Weight            8410 non-null   object
#  16  BODY_Build             2277 non-null   object
#  17  BODY_SIM               8437 non-null   object
#  18  DISPLAY_Type           8436 non-null   object
#  19  DISPLAY_Size           8359 non-null   object
#  20  DISPLAY_Resolution     8426 non-null   object
#  21  DISPLAY_Protection     2405 non-null   object
#  22  PLATFORM_OS            6950 non-null   object
#  23  PLATFORM_Chipset       5982 non-null   object
#  24  PLATFORM_CPU           6824 non-null   object
#  25  PLATFORM_GPU           5915 non-null   object
#  26  MEMORY_Card_slot       8438 non-null   object
#  27  MEMORY_Internal        7930 non-null   object
#  28  MAIN_CAM_1_Module      8438 non-null   int64
#  29  MAIN_CAM_1_Features    6016 non-null   object
#  30  MAIN_CAM_1_Video       7959 non-null   object
#  31  SELFIE_CAM_2_Module    8438 non-null   int64
#  32  SELFIE_CAM_2_Features  2016 non-null   object
#  33  SELFIE_CAM_2_Video     3459 non-null   object
#  34  SOUND_Loudspeaker      8438 non-null   object
#  35  SOUND_35mm_jack        8410 non-null   object
#  36  COMMS_WLAN             8432 non-null   object
#  37  COMMS_Bluetooth        8437 non-null   object
#  38  COMMS_GPS              8414 non-null   object
#  39  COMMS_NFC              6091 non-null   object
#  40  COMMS_Radio            8395 non-null   object
#  41  COMMS_USB              8399 non-null   object
#  42  FEATURES_Sensors       6769 non-null   object
#  43  BATTERY_Type           8430 non-null   object
#  44  BATTERY_Stand_by       3720 non-null   object
#  45  BATTERY_Talk_time      4060 non-null   object
#  46  BATTERY_Music_play     643 non-null    object
#  47  MISC_Colors            8378 non-null   object
#  48  MISC_SAR               2286 non-null   object
#  49  MISC_SAR_EU            2251 non-null   object
#  50  MISC_Models            3603 non-null   object
#  51  MISC_Price             8438 non-null   object
#  52  MISC_Price_Euro        8438 non-null   float64
# dtypes: float64(1), int64(2), object(50)
# memory usage: 3.5+ MB

# %%
df.drop(['MISC_Price'], axis=1, inplace=True)

# %% [markdown]
# ### Brand, url and Name

# %%
# #label encoding for Brand, drop url, imgUrl, Name
# from sklearn.preprocessing import LabelEncoder
# enc_brand = LabelEncoder()
# df['Brand'] = enc_brand.fit_transform(df['Brand'])
# df = df.drop(['url', 'imgUrl', 'Name'], axis=1)

# %% [markdown]
# #### Người ta bảo `brand` hay bị giá ảo -> test liền `target encoding` (hoặc `CatBoost` để tránh overfit)
# - Phương pháp này giúp encode các biến category thành mean của target tương ứng với category đó
# - Có thể dùng `smoothing` để tránh overfitting (mặc định là đã dùng)

# %% [markdown]
# `target enc`

# %%
# enc_brand = TargetEncoder(target_type ="continuous")
# df['Brand'] = enc_brand.fit_transform(np.array(df['Brand']).reshape(-1, 1), df['MISC_Price_Euro'])
# df_na['Brand'] = enc_brand.transform(np.array(df_na['Brand']).reshape(-1, 1))
# df = df.drop(['url', 'imgUrl', 'Name'], axis=1)
# df_na = df_na.drop(['url', 'imgUrl', 'Name'], axis=1)

# %%
enc_brand = CatBoostEncoder()
enc_brand = enc_brand.fit(df['Brand'], df['MISC_Price_Euro'])
df['Brand'] = enc_brand.transform(df['Brand'])
df_na['Brand'] = enc_brand.transform(df_na['Brand'])
# df_na['Brand'].fillna(df['Brand'].mean(), inplace=True)
df = df.drop(['url', 'imgUrl', 'Name'], axis=1)
df_na = df_na.drop(['url', 'imgUrl', 'Name'], axis=1)

# %%
df_na['Brand'].isnull().sum()
# Out:
# 0

# %%
df[['Brand', 'MISC_Price_Euro']].head(10)
# Out:
#     Brand  MISC_Price_Euro
# 0  175.03           330.23
# 1  175.03           172.48
# 2  175.03           252.01
# 3  175.03           126.63
# 4  175.03           236.09
# 5  175.03           238.03
# 7  175.03           200.78
# 8  175.03           113.80
# 9  175.03           350.27
# 10 175.03           221.97

# %%
df[['Brand']].value_counts().sort_values(ascending=False).head(10)
# Out:
# Brand
# 202.40    1125
# 148.27     522
# 138.99     470
# 181.72     449
# 323.77     402
# 315.14     370
# 275.17     349
# 323.02     270
# 260.86     263
# 210.70     259
# dtype: int64

# %% [markdown]
# ### Network_2345G

# %%
df[['NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands']].head(10)
# Out:
#                                                      NETWORK_2G_bands  \
# 0                                                                 N/A
# 1                         GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 2   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (dual-SIM model only)
# 3   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (dual-SIM model only)
# 4                                                                 N/A
# 5                                        GSM 850 / 900 / 1800 / 1900
# 7   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (dual-SIM model only)
# 8   GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (dual-SIM model only)
# 9                                                                 N/A
# 10                        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
#
#                                   NETWORK_3G_bands  \
# 0                                              NaN
# 1                         HSDPA 850 / 1900 / 2100
# 2                                            HSDPA
# 3                                            HSDPA
# 4                                              NaN
# 5         HSDPA 900 / 1900 / 2100 - Europe, Taiwan
# 7                                            HSDPA
# 8                   HSDPA 850 / 900 / 1900 / 2100
# 9                                              NaN
# 10  HSDPA 850 / 900 / 1900 / 2100 - Europe/ Taiwan
#
#                           NETWORK_4G_bands NETWORK_5G_bands
# 0                                      NaN              NaN
# 1                           1, 3, 7, 8, 20              NaN
# 2                        LTE (unspecified)              NaN
# 3                        LTE (unspecified)              NaN
# 4                                      NaN              NaN
# 5    LTE 800 / 1800 / 2100 / 2600 - Europe              NaN
# 7                        LTE (unspecified)              NaN
# 8                        LTE (unspecified)              NaN
# 9                                      NaN              NaN
# 10   LTE 800 / 1800 / 2100 / 2600 - Europe              NaN

# %%
print("2G number of unique values: ", df['NETWORK_2G_bands'].nunique())
print("3G number of unique values: ", df['NETWORK_3G_bands'].nunique())
print("4G number of unique values: ", df['NETWORK_4G_bands'].nunique())
print("5G number of unique values: ", df['NETWORK_5G_bands'].nunique())
# Out:
# 2G number of unique values:  199
# 3G number of unique values:  588
# 4G number of unique values:  1458
# 5G number of unique values:  402

# %% [markdown]
# #### Target Encoding

# %%
enc_network = CatBoostEncoder()
df[['NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands']] = enc_network.fit_transform(df[['NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands']], df['MISC_Price_Euro'])
df_na[['NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands']] = enc_network.transform(df_na[['NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands']])

# %%
df[['NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands']].head(10)
# Out:
#     NETWORK_2G_bands  NETWORK_3G_bands  NETWORK_4G_bands  NETWORK_5G_bands
# 0             227.52            227.52            227.52            227.52
# 1             227.52            227.52            227.52            278.87
# 2             227.52            227.52            227.52            243.41
# 3             239.76            239.76            239.76            245.56
# 4             278.87            278.87            278.87            221.77
# 5             227.52            227.52            227.52            224.16
# 7             202.05            202.05            202.05            226.14
# 8             201.73            227.52            201.73            222.97
# 9             264.61            264.61            264.61            210.84
# 10            200.00            227.52            232.77            224.78

# %% [markdown]
# ### Network GPRS EDGE SPEED

# %%
df[['NETWORK_GPRS','NETWORK_EDGE']].value_counts()
# Out:
# NETWORK_GPRS                            NETWORK_EDGE
# No                                      No                                 517
# Class 10                                Class 10                           317
# Yes                                     Yes                                279
# Class 10                                No                                 232
# Yes                                     No                                 148
# Class 12                                Class 12                           102
#                                         No                                  41
# Class 10                                Yes                                 40
# Class 12                                Yes                                 28
# Class 32                                Class 32                            19
# Class 8                                 No                                  17
# Class 10                                Class 6                             16
# Up to 85.6 kbps                         Up to 236.8 kbps                    15
# Class 12                                Class 10                             8
# Class 10                                Class 12                             4
# Up to 48 kbps                           No                                   4
# Class 6                                 No                                   3
# Up to 42.8 kbps                         Up to 236.8 kbps                     3
# Yes                                     Class 12                             3
# No  (Planned GPRS version for Q4 2012)  No                                   2
# No                                      Yes                                  2
# Up to 85.6 kbps                         No                                   1
# Yes                                     Up to 384 kbps                       1
# Up to 60 kbps                           Up to 177 kbps                       1
# Up to 59.2 kbps                         Up to 236.8 kbps                     1
# Yes                                     Up to 236.8 kbps                     1
# Up to 86 kbps                           Up to 237 kbps                       1
# Up to 115 kbps                          Up to 200 kbps                       1
# Yes                                     Class 32                             1
# Up to 80 kbps                           Up to 237 kbps                       1
# Class 4                                 No                                   1
# No                                      Class 10                             1
# Class 12                                Class 6 (Up to 177.6 kbps)           1
# Class 10                                Class 32                             1
#                                         Class 6 (downlink only)              1
#                                         Class 8                              1
#                                         Yes, 118.4 kbps                      1
# Class 11                                Class 10                             1
#                                         Class 11                             1
# Class 12                                Class 32                             1
# Class 32                                Class 10                             1
# Class 8                                 Class 8                              1
# Class 32                                Class 32,  up to 177 kbits           1
#                                         Class 32, 296 / 178.8 kbits          1
# Class 32,  88 kbps                      Class 32, 296 kbits                  1
# Class 32, 100 kbps                      Class 32, 296 kbits                  1
# Class 33                                Class 33                             1
# Class 10                                Class 10 (SIM 1, download only)      1
# Class 8                                 Class 10                             1
# Yes                                     Yes, DL only                         1
# dtype: int64

# %%
df[['NETWORK_GPRS','NETWORK_EDGE']].nunique()
# Out:
# NETWORK_GPRS    21
# NETWORK_EDGE    22
# dtype: int64

# %%
enc_gprs = LabelEncoder()
df['NETWORK_GPRS'] = enc_gprs.fit_transform(df['NETWORK_GPRS'])
df['NETWORK_EDGE'] = enc_gprs.fit_transform(df['NETWORK_EDGE'])
# df_na['NETWORK_GPRS'] = enc_gprs.transform(df_na['NETWORK_GPRS'])
# df_na['NETWORK_EDGE'] = enc_gprs.transform(df_na['NETWORK_EDGE'])

# %%
df[['NETWORK_Speed', 'NETWORK_Technology']].head(10)
# Out:
#                                         NETWORK_Speed  \
# 0                                                 NaN
# 1           HSPA 42.2/11.5 Mbps, LTE Cat4 150/50 Mbps
# 2           HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps
# 3                                           HSPA, LTE
# 4                                                 NaN
# 5           HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps
# 7                                           HSPA, LTE
# 8                          HSPA, LTE Cat4 150/50 Mbps
# 9                                                 NaN
# 10  HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps
#
#           NETWORK_Technology
# 0   No cellular connectivity
# 1           GSM / HSPA / LTE
# 2           GSM / HSPA / LTE
# 3           GSM / HSPA / LTE
# 4   No cellular connectivity
# 5           GSM / HSPA / LTE
# 7           GSM / HSPA / LTE
# 8           GSM / HSPA / LTE
# 9   No cellular connectivity
# 10          GSM / HSPA / LTE

# %%
df['NETWORK_Technology'].unique()
# Out:
# array(['No cellular connectivity', 'GSM / HSPA / LTE', 'GSM / HSPA',
#        'GSM', 'GSM / UMTS', 'GSM / CDMA / HSPA / LTE', 'LTE',
#        'CDMA / EVDO', 'GSM / HSPA / EVDO / LTE',
#        'GSM / CDMA / HSPA / EVDO / LTE / 5G', 'GSM / HSPA / LTE / 5G',
#        'GSM / CDMA / HSPA / EVDO / LTE', 'GSM / CDMA / HSPA / EVDO',
#        'GSM / CDMA / HSPA / LTE / 5G', 'GSM / LTE', 'HSPA / LTE',
#        'GSM / CDMA / EVDO', 'GSM / CDMA / HSPA / CDMA2000 / LTE / 5G',
#        'GSM / CDMA / HSPA / CDMA2000 / LTE', 'GSM / CDMA',
#        'GSM / HSPA / EVDO / LTE / 5G', 'LTE / 5G',
#        'GSM / CDMA / EVDO / LTE', 'GSM / CDMA / HSPA',
#        'CDMA / EVDO / LTE', 'CDMA / HSPA / EVDO / LTE',
#        'GSM / UMTS / HSPA', 'GSM / HSPA / EVDO', 'CDMA / LTE',
#        'CDMA / CDMA2000', 'CDMA', 'HSPA / EVDO', 'CDMA / HSPA',
#        'CDMA / HSPA / EVDO', 'GSM / CDMA2000', 'GSM / UMTS / LTE',
#        'CDMA / HSPA / LTE', 'GSM / UMTS / HSPA / LTE', 'HSPA',
#        'GSM / CDMA / UMTS / EVDO', 'GSM / HSPA / CDMA2000',
#        'GSM / HSPA / CDMA2000 / LTE', 'GSM / HSPA / CDMA2000 / LTE / 5G'],
#       dtype=object)

# %%
df['NETWORK_Speed'].unique()
# Out:
# array([nan, 'HSPA 42.2/11.5 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps', 'HSPA, LTE',
#        'HSPA, LTE Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps', 'HSPA 21.1/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA', 'HSPA 21.1/5.76 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat4 150/50 Mbps',
#        'HSPA 7.2/5.76 Mbps', 'HSPA 7.2/0.384 Mbps', 'HSPA 14.4/5.76 Mbps',
#        'HSPA 7.2/2 Mbps', 'TD-SCDMA', 'HSPA 14.4/2 Mbps',
#        'HSPA 3.6/0.384 Mbps', 'HSPA 42.2/11.1 Mbps, LTE Cat4 150/50 Mbps',
#        'LTE', 'No', 'HSPA 42.2/11.5 Mbps, LTE-A (2CA) Cat6 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps or LTE-A (2CA) Cat6 300/50 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE', 'HSPA 42.2/11.5 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat3 100/50 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE Cat3 100/50 Mbps',
#        'EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE Cat7 300/100 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE-A (2CA) Cat7 300/150 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps',
#        'HSPA, LTE-A, 5G, EV-DO Rev.A 3.1 Mbps', 'HSPA, LTE-A, 5G',
#        'HSPA, LTE-A (CA), 5G, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE-A (CA), 5G', 'HSPA, LTE-A (CA)',
#        'HSPA, LTE-A, EV-DO Rev.A 3.1 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1024/150 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE-A, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE-A 1.6 Gbps DL, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat16 1024/150 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat16 1024/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat16 1024/150 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat6 300/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat12 600/150 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat9 450/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE-A Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat3 100/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE, EV-DO Rev.A 3.1 Mbps', 'HSPA, LTE-A',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat9 450/50 Mbps',
#        'HSPA, LTE-A (Up to 7CA), 5G',
#        'HSPA 42.2/11.5 Mbps, LTE-A (5CA) Cat19 1600/210 Mbps, 5G',
#        'Up to HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2024/210 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2024/210 Mbps, 5G - Snapdragon modelHSPA 42.2/11.5 Mbps, LTE-A (5CA) Cat19 1600/210 Mbps, 5G - MediaTek mod',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat20 2000/211 Mbps, 5G 4.5/0.9 Gbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2024/210 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat20 1400/150 Mbps, 5G 4 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2000/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat20 2000/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat19 1800/150 Mbps, 5G 3.6 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2000/150 Mbps, 5G 4.4 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat18 1200/150 Mbps, 5G 4.0 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 (Cat20 Ultimate edition) 1200/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat7 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 400/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 400/75 Mbps (SDM630)HSPA 42.2/5.76 Mbps, LTE Cat4 150/75 Mbps (MSM8937)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 400/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat12 600/150 or 100 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat12 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 MbpsLTE-A (2CA) Cat6 300/50 Mbps - TW/JP/HK',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat12 600/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps (Global), LTE-A (2CA) Cat6 300/50 Mbps (Taiwan)',
#        'LTE-A Cat6 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps (Global) or LTE-A (2CA) Cat6 300/50 Mbps (TW/HK/SG/PH)',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4+ 250/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4+ 250/50 Mbps, LTE-A (2CA) Cat6 300/50 Mbps (Special Edition)',
#        'TD-SCDMA, TD-LTE', 'HSPA 42.2/5.76 Mbps/ LTE (ME372CL)',
#        'Yes, 384 kbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat12 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat11 600/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat9 450/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE, EV-DO Rev.A 3.1 Mbps',
#        'EV-DO Rev.A 3.1 Mbps, HSPA, LTE (market dependent)',
#        'HSPA 14.4/5.76 Mbps, EV-DO Rev A 3.1 Mbps',
#        'HSPA 14.4/5.76 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 7.2/2 Mbps, EV-DO RevA 3.1 Mbps', 'EV-DO Rev.0, 153.2 Kbps',
#        'HSPA, LTE, 5G', 'HSPA 42.2/5.76 Mbps, LTE Cat6 300/50 Mbps',
#        'HSPA 21.1/11.5 Mbps', 'EV-DO Rev.A 3.1 Mbps, HSPA, LTE',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat12 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 400/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/100 Mbps',
#        'HSPA 7.2/3.6 Mbps', 'HSPA, LTE-A (2CA)',
#        'HSPA, LTE-A, 5G (2+ Gbps DL)', 'HSPA/LTE (optional)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 600/50 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 1.8 Mbps', 'HSPA, LTE-A (4CA), 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat18 1200/150 Mbps, 5G 2.3 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1024/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat15 800/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat9 450/50 Mbps or LTE-A (3CA) Cat11 600/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat12 600/50 Mbps, 5G 2.3 Gbps DL',
#        'LTE-A, 5G', 'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat12 600/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat21 1400/200 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat16 1024/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat18 1200/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat6 300/50 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE-A Cat6 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A, Cat6 300/75 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE Cat4 150/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat15 800/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat15 800/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat16 1024/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat11 600/50 Mbps',
#        'HSPA 42.2/21.1 Mbps, LTE-A (2CA) Cat6 300/50 Mbps',
#        'HSPA, LTE-A (3CA) Cat9 450/50 Mbps',
#        'HSPA, LTE-A Cat7 (2CA) 300/100 Mbps',
#        'HSPA 42.2/21.1 Mbps, LTE-A Cat6 300/50 Mbps',
#        'HSPA 42.2/21.1(AT&T)/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 14.4/5.76 Mbps, LTE Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 14.4/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 14.4/5.76 Mbps, EV-DO Rev. B', 'HSPA, LTE Cat3 100/50 Mbps',
#        'EV-DO Rev.A 3.1 Mbps, LTE',
#        'HSPA, LTE Cat3 100/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'LTE Cat3 100/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 21.1/5.76 Mbps - Global versionHSPA 42.2/5.76 Mbps, LTE Cat3 100/50 Mbps - AT&T version',
#        'HSPA, LTE Cat3 100/50 Mbps, EV-DO Rev.A 3.1 Mbps (LTE for AT&T version)',
#        'HSPA, LTE, EV-DO Rev. A 3.1 Mbps',
#        'EV-DO Rev.A 3.1 Mbps, LTE Class 13', 'EV-DO Rev.A 3.1 Mbps, HSPA',
#        'HSPA 14.4/5.76 Mbps, LTE',
#        'HSPA 7.2/2 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'EV-DO Rev.A 3.1 Mbps / HSPA',
#        'HSPA 14.4/5.76 Mbps or HSPA 7.2/2 Mbps (carrier dependent)',
#        'EV–DO Rev. A',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 400/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat21 1400/200 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat7 300/150 Mbps',
#        'HSPA 42.2/3.6 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA, TD-SCDMA, LTE, TD-LTE',
#        'HSPA 21.1/5.76 Mbps, EV-DO Rev. A 3.1 Mbps (version for China)',
#        'CDMA2000 1x, 153 Kbps', '384 Kbps',
#        'HSPA 14.4/5.76 Mbps(U8800H)/ 7.2/2 Mbps(U8800)',
#        'HSPA 42.2/11.5 Mbps, LTE Cat7 300/75 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A Cat7 300/75 Mbps, 5G',
#        'HSPA 42.2/11.5 Mbps, LTE Cat7 300/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat7 300/100 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat13 390/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat15 800/210 Mbps, 5G 2.5 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/150 Mbps, 5G (2+ Gbps DL)',
#        'HSPA - 3G model', 'EV-DO Rev.A 3.1 Mbps, HSPA (region dependent)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1000/75 Mbps, 5G 2Gbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat22, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat19 1600/75 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat20 1960/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat18 1200/75 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat19 1600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat16 1024/150 Mbps',
#        'HSPA, LTE-A (2CA), EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat16 1024/150 Mbps or Cat15 800/150 Mbps (region dependant)',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat6, Cat9 (3CA) or LTE-A Cat12 (3CA) 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat6 300/50 Mbps or LTE-A Cat9 (3CA) 450/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA (roaming, voice only), LTE Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/21.1 Mbps, LTE-A Cat6 300/50 MbpsLTE-A, EV-DO Rev.A 3.1 Mbps - US995 (U.S. Cellular)',
#        'LTE, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE Cat4 150/50 Mbps (LS990)LTE Cat4, EV-DO Rev.A 3.1 Mbps (VS985)',
#        'HSPA 42.2/21.1 Mbps, LTE Cat4 150/50 Mbps', 'CDMA, LTE',
#        'EV-DO Rev.A 3.1 Mbps, LTE, HSPA',
#        'HSPA 21.1/5.76 Mbps (req. SW update)', 'HSPA 10.2/2 Mbps',
#        'HSPA, EV-DO Rev. A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2000/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat15 800/150 Mbps',
#        'HSPA, LTE-A (2CA) Cat6 300/50 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A (2CA) Cat7 300/150 Mbps',
#        'CDMA2000 1x',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat20 2000/150 Mbps, 5G 6 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat18 1200/150 Mbps',
#        'HSPA, LTE (CA)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat20 2000/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat15 800/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat18 1200/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE Cat7 300/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat20 2000/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 600/100 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2000/200 Mbps, 5G 4 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1000/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat12 600/100 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1024/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps or LTE-A (2CA) Cat6 300/50 Mbps - USA only',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat13 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat9 450/50 Mbps, EV-DO Rev.A 3.1 Mbps - USAHSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps - Global',
#        'HSPA, LTE-A Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE, EV-DO Rev.B', 'HSPA, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 10.2/1.8 Mbps, EV-DO Rev.A 3.1 Mbps', 'HSPA 10.2/1.8 Mbps',
#        'HSPA 10.2/5.76 Mbps', 'EV-DO Rev.A 3.1 Mbps, 4G LTE upgradeable',
#        'HSPA 10.2/5.76 Mbps, EV-DO Rev.A 3.1 Mbps', 'TD-SCDMA, HSUPA',
#        'HSPA 3.6/2 Mbps', 'HSPA, LTE (2CA)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat18 1200/150 Mbps, 5G 2.4/1.2 Gbps',
#        'HSPA 21.1/5.76 Mbps, LTE, Cat6 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps or LTE Cat4 150/50 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA, LTE-A (3CA), 5G',
#        'HSPA 42.2/5.76 Mbps, LTE Cat13 390/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA), Cat20 2000/200 Mbps, 5GHSPA 42.2/5.76 Mbps, LTE-A (3CA), Cat16 1000/150 Mbps, 5G - India',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat15 800/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA), Cat12 600/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat18 1200/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat18 1200/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat15 800/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat18 1024/150 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat13 400/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/200 Mbps, 5G 7.5 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/150 Mbps, 5G 7.5 Gbps DL',
#        'HSPA, LTE-A, 5G 3.5 Gbps DL', 'HSPA, LTE-A (CA), 5G 2.3 Gbps DL',
#        'HSPA, LTE-A, 5G 3.7/1.6 Gbps', 'HSPA, LTE-A, 5G (1.9 Gbps DL)',
#        'HSPA, LTE-A, 5G 4.7/2.5 Gbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps or LTE-A Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps - 4G modelHSPA 21.1/5.76 Mbps - 3G model',
#        'TD-SCDMA, LTE Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat18 1200/150 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 600/50 Mbps',
#        'HSPA, LTE, EV-DO Rev. A', 'HSPA, LTE-A, 5G 2.3 Gbps DL',
#        'HSPA 42.2/11.5 Mbps, LTE-A (2CA) Cat6 300/75 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A (2CA) Cat6 300/150 Mbps',
#        'HSPA, LTE-A (2CA) 450/50 Mbps', 'HSPA, LTE-А, 5G',
#        'HSPA, LTE-A (up to 7CA), 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat13 400/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat20 2000/200 Mbps, 5G',
#        'HSPA, LTE-A (6CA), 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat19 1800/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat20 2000/200 Mbps, 5G (5+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat19 1600/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2000/200 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat16 1024/75 Mbps, 5G',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat19 1800/200 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat20 2000/200 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1000/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat20 2000/150 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat18 1200/150 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat18 1200/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat20 2000/150 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (7CA) Cat20 2000/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat18 1200/200 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat18 1200/200 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat12 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat9/Cat10 or LTE-A (3CA) Cat12 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat6 300/50 Mbps',
#        'HSPA, LTE-A (3CA), EV-DO Rev.A 3.1 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat6 300/50 Mbps/ LTE-A (3CA) Cat9 450/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat6 300/50 Mbps/ LTE-A (3CA) Cat9 450/50 Mbps',
#        'HSPA 21.1/5.76 MbpsHSPA, LTE Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat6 300/50 Mbps or Cat4 150/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps (Exynos 5433)HSPA 42.2/5.76 Mbps, LTE-A Cat6 300/50 Mbps (Snapdragon 805)',
#        'HSPA 42.2(LTE)/21.1(3G)/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'EV-DO Rev.A 3.1 Mbps, LTE-A Cat4 150/50 Mbps, HSPA',
#        'HSPA 42.2/5.76 Mbps (T321)/ LTE Cat4 150/50 Mbps (T325)',
#        'HSPA 42.2/21/5.76 Mbps (region dependent)/ LTE Cat3 100/50 Mbps (SM-G7105)',
#        'HSPA 7.2/0.384 Mbps (GT-C3595)',
#        'HSPA 42.2(14.4 - 3G)/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 42.2(LTE)/21.1(3G)/5.76 Mbps, LTE Cat3 100/50 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE Cat3 100/50 Mbps (SM-T215)',
#        'HSPA 21.1/5.76 Mbps (I9200), LTE Cat3 100/50 Mbps (I9205)',
#        'HSPA 21.1/5.76 Mbps, LTE (optional)',
#        'HSPA 42.2/11.5 Mbps, LTE Cat3 100/50 Mbps', 'HSPA, LTE (T999L)',
#        'HSPA 21.1/3.6 Mbps', 'EV-DO Rev. 0', 'HSPA, CDMA2000 1xEV-DO',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat9 450/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat15 1024/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (6CA) Cat19 1600/150 Mbps, 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A Cat11 600/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat15 800/75 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (2CA) Cat16 1024/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps (E6603), LTE-A Cat6 300/50 Mbps (E6653)',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps (E5803), LTE-A Cat6 300/50 Mbps (E5823)',
#        'HSPA 42.2/21.1(D5102)/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 42.2(D2303, D2306)/21.1(D2305)/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 14.4/5.76 Mbps, LTE Cat2 50/25 Mbps', 'HSPA 2.8/2 Mbps',
#        'CDMA', 'HSPA 7.2/1.8 Mbps', 'HSPA 3.6/0.384 Mbps (K850i)',
#        'HSPA 3.6/0.384 Mbps (W910i)',
#        'HSPA 42.2/11.5 Mbps, LTE Cat13 390/150 Mbps, 5G',
#        'HSPA 42.2/11.5 Mbps, LTE Cat13 300/150 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A Cat13 400/100 Mbps, 5G 2.7 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE-A (CA) Cat18 1200/150 Mbps, 5G 2.7 Gbps DL, 625 Mbps UL',
#        'HSPA 21.1/5.76 Mbps, LTE, Cat4 150/50 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A Cat4 150/50 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A Cat6 300/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA) Cat16 1000/150 Mbps, 5G 2.3 Gbps DL',
#        'HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps, 5G',
#        'HSPA, LTE Cat13 300/150 Mbps',
#        'HSPA 21/5.76 Mbps, LTE Cat6 300/150 Mbps',
#        'HSPA 21.1/5.76 Mbps, LTE Cat7 300/150 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE Cat12 600/150 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A Cat7 300/150 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE Cat6 300/150 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE-A (2CA) Cat13 600/150 Mbps',
#        'HSPA, LTE-A, 5G (3.6+ Gbps DL)', 'HSPA, LTE-A (2CA), 5G',
#        'HSPA, LTE-A, 5G (3.3 Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE Cat5 150/75 Mbps', 'HSPA 21.1/7.2 Mbps',
#        'HSPA 2.8/2.2 Mbps', 'HSPA 3.6/0.384 Mbps  ', 'HSPA 21/5.76 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat12 600/50 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (5CA/3CA) Cat18 1200/150 Mbps',
#        'HSPA, LTE-A ', 'LTE-A (3CA) Cat12 600/150 Mbps',
#        'HSPA 42.2/5.76 Mbps, LTE-A (3CA) Cat18 1200/100 Mbps',
#        'HSPA 42.2/7.2 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA, LTE-A, 5G 7.5 Gbps DL',
#        'HSPA, LTE-A (3CA), 5G (2+ Gbps DL)',
#        'HSPA 42.2/5.76 Mbps, LTE-A (4CA) Cat18 1200/150 Mbps',
#        'HSPA 7.2/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA 42/5.76 Mbps, LTE Cat4 150/50 Mbps',
#        'HSPA, LTE Cat4 150/50 Mbps or Cat3 100/50 Mbps',
#        'HSPA 42.2/11.5 Mbps, LTE Cat4 150/50 Mbps, EV-DO Rev.A 3.1 Mbps',
#        'HSPA 14.4/5.76 Mbps, EV-DO Rev.A 3.1 Mbps (ZTE Render)'],
#       dtype=object)

# %% [markdown]
# 2 thằng sussy này có vẻ ảnh hưởng tới giá nhìu đó mấy ní => target encoding thui

# %%
#target encoding for NETWORK_Technology and NETWORK_Speed
enc_network_tech = CatBoostEncoder()
enc_network_speed = CatBoostEncoder()
df[['NETWORK_Technology']] = enc_network_tech.fit_transform(df[['NETWORK_Technology']], df['MISC_Price_Euro'])
df[['NETWORK_Speed']] = enc_network_speed.fit_transform(df[['NETWORK_Speed']], df['MISC_Price_Euro'])
df_na[['NETWORK_Technology']] = enc_network_tech.transform(df_na[['NETWORK_Technology']])
df_na[['NETWORK_Speed']] = enc_network_speed.transform(df_na[['NETWORK_Speed']])

# %% [markdown]
# ### Launch annouced với status ko liên quan lắm (có liên quan thì có lẽ là kiểu dựa vào đó rồi train riêng theo từng thời kì, nhưng mà mình chưa biết làm thế nào để xử lý nên thôi) (bin categorize)

# %% [markdown]
# ### Body dim, weight, build

# %%
# #return indexes of rows with foldable body
# contains_folded = df['BODY_Build'].str.contains("Unfolded")
# #IF value is True, return index of row
# folded_indices = df[contains_folded].index.tolist()
# #calculate mean of BODY_Dimensions and BODY_Weight for foldable phones 
# mean_body_dimensions = df.iloc[folded_indices]['BODY_Dimensions'].mean()
# #replace foldable phones BODY_Dimensions with mean
# df.loc[folded_indices, 'BODY_Dimensions'] = mean_body_dimensions

# %%
# # method 1: (bad)

# def is_folded(dim):
#     if dim.startswith("Unfolded"):
#         return True
#     return False


# def body_dim_volume_calc(dimensions):
#     # Extract the numerical values from the string
    
#     if pd.isnull(dimensions) or dimensions == '-' or ("thickness" in dimensions):
#         return np.nan
#     dims = re.findall(r'(\d+\.?\d*)', dimensions)
#     # Convert the strings to floats and calculate the volume (2 decimal places)
#     volume = float(dims[0]) * float(dims[1]) * float(dims[2])
#     volume = round(volume, 2)
#     return volume

# dim_test = "238.3 x 172.2 x 9.9 mm (9.38 x 6.78 x 0.39 in)"
# print(body_dim_volume_calc(dim_test))

# %% [markdown]
# #### body dimensions:

# %%
df.BODY_Dimensions[df.BODY_Dimensions=='-'].value_counts()
# Out:
# -    153
# Name: BODY_Dimensions, dtype: int64

# %%
def dim_extractor(dim):
    extracts = dim.astype(str).apply(lambda x:
        re.findall('(\d*\.\d*|\d*)\sx\s(\d*\.\d*|\d*)\sx\s(\d*\.\d*|\d*)',x))
    return extracts

body_dim_extracts_abc = dim_extractor(df.BODY_Dimensions)
body_dim_extracts_abc_na = dim_extractor(df_na.BODY_Dimensions)

# %%
#check lỗi khi extract trừ null và "-":
df.BODY_Dimensions[body_dim_extracts_abc.apply(lambda x: len(x)==0) & ~df.BODY_Dimensions.isnull() & (df.BODY_Dimensions!='-')]
df_na.BODY_Dimensions[body_dim_extracts_abc_na.apply(lambda x: len(x)==0) & ~df_na.BODY_Dimensions.isnull() & (df_na.BODY_Dimensions!='-')]
# Out:
# 960      205.2 mm x 136.4 mm x (unknown thickness) mm
# 1313                                 9.5 mm thickness
# 2285                             ⁓ 30-40 mm thickness
# 3163                                   8 mm thickness
# 3823                           156.8 x Unknown x 8 mm
# 3824                           156.8 x Unknown x 8 mm
# 4867                                11.9 mm thickness
# 5303                                   7 mm thickness
# 6071                                           100 cc
# 6811                    118 x 42-50 x 18-21 mm, 98 cc
# 6831                   142 x 50-58 x 23-27 mm, 159 cc
# 7243                                 7.9 mm thickness
# 7755                                     143.3 x 73.9
# 9680                                            85 cc
# 10043                                     8.6mm thick
# 12445                                7.8 mm thickness
# Name: BODY_Dimensions, dtype: object

# %%
body_dim_extracts_mm = df.BODY_Dimensions.astype(str).apply(lambda x: 
    (re.findall('(\d*\.\d*|\d*)\smm\sthickness',x)))

body_dim_extracts_mm_na = df_na.BODY_Dimensions.astype(str).apply(lambda x:
    (re.findall('(\d*\.\d*|\d*)\smm\sthickness',x)))

# %%
def dimension_conversion(regex):
    if len(regex) == 0: # empty regex
        return []
    elif len(regex) == 1 & isinstance(regex[0],str): 
        new_regex = []
        try:            
            new_regex.append(float(regex[0]))
        except:
            pass
        return new_regex
    elif (len(regex) >= 1) & isinstance(regex[0],tuple):
        new_regex = list(regex[0])
        for i in range(len(new_regex)):
            try:
                new_regex[i] = float(regex[0][i])
            except:
                pass
        return new_regex
    else:
        return []

# %%
body_dim_extracts = body_dim_extracts_abc.apply(lambda x: dimension_conversion(x)) + body_dim_extracts_mm.apply(lambda x: dimension_conversion(x))
body_dim_extracts_na = body_dim_extracts_abc_na.apply(lambda x: dimension_conversion(x)) + body_dim_extracts_mm_na.apply(lambda x: dimension_conversion(x))

# %%
def length(x):
    if len(x) == 3:
        if x[0] is not None:
            return x[0]
        else:
            return np.nan
    else:
        return np.nan
    
def width(x):
    if len(x) == 3:
        if x[1] is not None:
            return x[1]
        else:
            return np.nan
    else:
        return np.nan
    
def thickness(x):
    if len(x) == 3:
        if x[2] is not None:
            return x[2]
        else:
            return np.nan
    elif len(x) == 1:
        if x[0] is not None:
            return x[0]
        else:
            return np.nan
    else:
        return np.nan

# %%
# length = body_dim_extracts_na.apply(lambda x: length(x))
# width = body_dim_extracts_na.apply(lambda x: width(x))
# thickness = body_dim_extracts_na.apply(lambda x: thickness(x))
# df_na['BODY_Length'] = length
# df_na['BODY_Width'] = width
# df_na['BODY_Thickness'] = thickness

# %%
length = body_dim_extracts.apply(lambda x: length(x))
width = body_dim_extracts.apply(lambda x: width(x))
thickness = body_dim_extracts.apply(lambda x: thickness(x))

df['BODY_Length'] = length
df['BODY_Width'] = width
df['BODY_Thickness'] = thickness

# %%
df.drop(columns=['BODY_Dimensions'],inplace=True)
# df_na.drop(columns=['BODY_Dimensions'],inplace=True)

# %%
df[['BODY_Length', 'BODY_Width', 'BODY_Thickness']].head(10)
# Out:
#    BODY_Length  BODY_Width BODY_Thickness
# 0       238.30      172.20           9.90
# 1       191.70      101.00           9.40
# 2       153.80       75.60           8.50
# 3       145.50       72.50           8.50
# 4       259.00      167.00           8.90
# 5       153.30       78.80           8.50
# 7       154.00       77.00          10.00
# 8       145.70       71.20           8.40
# 9       217.90      127.00           8.60
# 10      156.50       75.90           8.40

# %%
def process_column(df, column_name):
    df[column_name] = df[column_name].replace('', np.nan)
    df[column_name] = df[column_name].astype(float)
    df[column_name] = df[column_name].fillna(df[column_name].mode()[0])
    return df

columns_to_process = ['BODY_Length', 'BODY_Width', 'BODY_Thickness']

for column in columns_to_process:
    df = process_column(df, column)
    # df_na = process_column(df_na, column)

# %%
df[['BODY_Length','BODY_Width','BODY_Thickness']].isnull().sum()
# Out:
# BODY_Length       0
# BODY_Width        0
# BODY_Thickness    0
# dtype: int64

# %% [markdown]
# `mean` target corr: 0.057675	0.045684	-0.093621

# %% [markdown]
# `median` target corr: 0.057805	0.045589	-0.094439

# %% [markdown]
# `mode` target corr: 0.059037	0.046763	-0.095828

# %%
#plot distribution of BODY_Length, BODY_Width, BODY_Thickness to see if they are skewed
fig, ax = plt.subplots(1,3, figsize=(20,5))
sns.distplot(df.BODY_Length, ax=ax[0])
sns.distplot(df.BODY_Width, ax=ax[1])
sns.distplot(df.BODY_Thickness, ax=ax[2])
# Out:
# <AxesSubplot: xlabel='BODY_Thickness', ylabel='Density'>

# %% [markdown]
# #### BODY WEIGHT:

# %%
#take the number before "g"
df.BODY_Weight = df.BODY_Weight.astype(str).apply(lambda x: x.split("g")[0])
#remove before number and after number
df.BODY_Weight = df.BODY_Weight.astype(str).apply(lambda x: np.nan if "-" in x else x)
df.BODY_Weight = df.BODY_Weight.astype(str).apply(lambda x: re.findall(r'\d+',x)[0] if re.findall(r'\d+',x) else np.nan)
#if "-" in string make it null
#change to float
df.BODY_Weight = df.BODY_Weight.astype(float)

# %%
# #take the number before "g"
# df_na.BODY_Weight = df_na.BODY_Weight.astype(str).apply(lambda x: x.split("g")[0])
# #remove before number and after number
# df_na.BODY_Weight = df_na.BODY_Weight.astype(str).apply(lambda x: np.nan if "-" in x else x)
# df_na.BODY_Weight = df_na.BODY_Weight.astype(str).apply(lambda x: re.findall(r'\d+',x)[0] if re.findall(r'\d+',x) else np.nan)
# #if "-" in string make it null
# #change to float
# df_na.BODY_Weight = df_na.BODY_Weight.astype(float)

# %%
# df_na.BODY_Weight.isnull().sum()

# %%
#fillin with mean
df.BODY_Weight = df.BODY_Weight.fillna(df.BODY_Weight.mean())

# %%
#plot the dist 
sns.distplot(df.BODY_Weight)
# Out:
# <AxesSubplot: xlabel='BODY_Weight', ylabel='Density'>

# %% [markdown]
# #### BODY BUILD: DROP

# %% [markdown]
# #### sensors

# %% [markdown]
# tách từng sensor ra

# %%
def find_unique_values(series):
    unique_values = set()
    for value in series:
        if isinstance(value, str):  # Only process string values
            sensors = value.split(', ')
            for sensor in sensors:
                unique_values.add(sensor)
    return list(unique_values)

sensors = find_unique_values(df.FEATURES_Sensors)
sensors = sorted(sensors)
len(sensors)
# Out:
# 120

# %% [markdown]
# mean của từng sensor:

# %%
# Split the 'FEATURES_Sensors' column into separate sensors
df_sensors = df['FEATURES_Sensors'].str.split(', ', expand=True).stack()

# Create a new DataFrame with the individual sensors and the corresponding 'MISC_Price_Euro' values
df_individual_sensors = df.loc[df_sensors.index.get_level_values(0), ['MISC_Price_Euro']].copy()
df_individual_sensors['Sensor'] = df_sensors.values

# Calculate the mean 'MISC_Price_Euro' for each sensor
sensor_means = df_individual_sensors.groupby('Sensor')['MISC_Price_Euro'].mean()

# Now sensor_means is a Series where the index is the sensor name and the value is the mean 'MISC_Price_Euro'
sensor_means
# Out:
# Sensor
# 32/3GB only)                                                   146.48
# 5008T only)                                                    125.75
# 5059A/J only)                                                  108.36
# 7041D only)                                                    136.47
# AL00)                                                          246.04
# Accelerometer                                                  201.37
# Ambient light sensor                                           176.73
# Barometer                                                      196.25
# Compass                                                        129.78
# Dual fingerprint (side-mounted)                                500.99
# Dual screen fingerprint (under display                        1330.80
# Face ID                                                        852.15
# Face recognition                                               380.13
# Fingerprint (Exclusive edition only; side-mounted)             355.79
# Fingerprint (front-mounted                                     141.62
# Fingerprint (front-mounted)                                    318.10
# Fingerprint (rear-mounted                                      357.06
# Fingerprint (rear-mounted)                                     210.37
# Fingerprint (rear-mounted) - only 4 GB model; accelerometer    187.15
# Fingerprint (rear-mounted; region dependent)                   184.77
# Fingerprint (side-mounted                                      234.52
# Fingerprint (side-mounted)                                     285.82
# Fingerprint (side-mounted); unspecified sensors                333.63
# Fingerprint (side-mounted; EU model only)                      178.16
# Fingerprint (top-mounted)                                      592.28
# Fingerprint (under display                                     463.74
# Fingerprints (rear-mounted and under display                  1304.46
# Gyro                                                            98.68
# Hand ID                                                        357.77
# Infrared Face ID                                               401.56
# Iris scanner                                                   435.94
# No                                                              44.73
# Proximity                                                       86.05
# SpO2                                                           299.71
# ToF proximity                                                  271.90
# UV                                                             305.65
# UV light                                                       307.09
# Unspecified                                                    362.23
# VO2max                                                         493.95
# Yes                                                            212.83
# accelerometer                                                  318.20
# accelerometer (2)                                              176.73
# accelerometer proximity                                        213.51
# altimeter                                                      360.97
# always-on altimeter                                            551.27
# always-on altimeter (-500m to 9000m)                            63.13
# ambient light sensor                                           169.00
# baroceptor                                                     402.37
# barometer                                                      475.76
# barometer (C6502 only)                                         264.51
# barometer (China only)                                         613.68
# barometer (North America only)                                 759.99
# barometer (USA only)                                           441.68
# barometer (market dependant)                                   355.96
# body composition (BMI)                                         154.15
# color spectrum                                                 620.54
# compass                                                        303.90
# compass (7041X                                                 136.47
# compass (LTE model only)                                       214.56
# compass (USA model only)                                       245.69
# compass (market dependent)                                     201.43
# compass (optional)                                             126.00
# compass - India only                                           234.72
# compass - North AmericaAccelerometer                           224.83
# compassFingerprint (rear-mounted)                              234.72
# coulombmeter                                                   351.91
# differential pressure sensor                                   384.00
# dual accelerometer                                             978.73
# dual compass                                                   978.73
# dual gyro                                                     1148.83
# dual proximity                                                1296.45
# fingerprint (front-mounted)                                    709.29
# fingerprint (rear-mounted)                                     360.76
# fingerprint (side-mounted)                                     320.92
# fingerprint (under display                                     889.26
# gesture                                                        389.17
# gravity                                                        137.67
# grip                                                           448.91
# gyro                                                           366.55
# gyro (5G model only)                                           652.20
# gyro (Bach-L09 only)                                           255.82
# gyro (digital)                                                 139.83
# gyro (except LX2                                               246.04
# gyro (market dependent)                                        150.33
# gyro (optional)                                                374.88
# gyroscope                                                      169.00
# heart rate                                                     423.99
# heart rate (2nd gen)                                           260.76
# humidity                                                       439.30
# indoor air quality sensor                                      901.30
# infrared thermometer                                          1400.70
# infrared thermometer (surface temperature)                     314.25
# laser rangefinder                                              308.28
# market/region dependent)                                       156.03
# optical)                                                       470.32
# optical) - market dependant                                     88.21
# proximity                                                      259.90
# proximity (3G/LTE models only)                                 273.70
# proximity (4002X)                                               92.39
# proximity (8704X/8704N only)                                   204.07
# proximity (LTE model only)                                     175.70
# proximity (accessories only)                                   327.10
# proximity (incl. for accessories)                              514.24
# proximity (ultrasound)                                         283.20
# proximity - other markets                                      224.83
# proximity sensor                                               176.73
# proximity/ gyro                                                151.81
# region dependent)                                              178.35
# sensor core                                                    246.36
# skin conductance                                               359.45
# temperature                                                    385.09
# temperature (body)                                             499.52
# temperature (water)                                            383.56
# thermometer                                                    297.91
# thermometer (body temperature)                                 510.67
# thermometer (skin temperature)                                 394.85
# ultrasonic)                                                    659.82
# ultrasound proximity                                           398.75
# unspecified sensors                                            176.69
# Аccelerometer                                                   73.70
# Name: MISC_Price_Euro, dtype: float64

# %%
# Calculate the mean 'MISC_Price_Euro' for each sensor
sensor_means = df_individual_sensors.groupby('Sensor')['MISC_Price_Euro'].mean()
# Replace each sensor in 'FEATURES_Sensors' with its mean 'MISC_Price_Euro' and calculate the mean for each row
df['FEATURES_Sensors'] = df['FEATURES_Sensors'].apply(lambda x: np.mean([sensor_means.get(sensor, 0) for sensor in x.split(', ')] if isinstance(x, str) else [0]))

# Now 'Mean_Price_Euro' is a new column in df where each value is the mean 'MISC_Price_Euro' of the sensors in the corresponding row
df[['Mean_Price_Euro', 'FEATURES_Sensors']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[216], line 7
#       4 df['FEATURES_Sensors'] = df['FEATURES_Sensors'].apply(lambda x: np.mean([sensor_means.get(sensor, 0) for sensor in x.split(', ')] if isinstance(x, str) else [0]))
#       6 # Now 'Mean_Price_Euro' is a new column in df where each value is the mean 'MISC_Price_Euro' of the sensors in the corresponding row
# ----> 7 df[['Mean_Price_Euro', 'FEATURES_Sensors']].head()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Mean_Price_Euro'] not in index"

# %%
#apply Mean_Price_Euro for FEATURES_Sensors column in df
df['FEATURES_Sensors'] = df['Mean_Price_Euro']
df.head()
# Out:
#    Brand  NETWORK_Technology  NETWORK_2G_bands  NETWORK_3G_bands  \
# 0 175.03              227.52            227.52            227.52
# 1 175.03              227.52            227.52            227.52
# 2 175.03              200.00            227.52            227.52
# 3 175.03              217.34            239.76            239.76
# 4 175.03              278.87            278.87            278.87
#
#    NETWORK_4G_bands  NETWORK_5G_bands  NETWORK_GPRS  NETWORK_EDGE  \
# 0            227.52            227.52            10            13
# 1            227.52            278.87            21            22
# 2            227.52            243.41            20            19
# 3            239.76            245.56            20            19
# 4            278.87            221.77            10            13
#
#    NETWORK_Speed                       LAUNCH_Announced  \
# 0         227.52                            2018, March
# 1         227.52   2016, August. Released 2016, October
# 2         227.52  2016, August. Released 2016, December
# 3         227.52  2016, August. Released 2016, December
# 4         278.87       2016, April. Released 2016, June
#
#                     LAUNCH_Status  BODY_Weight BODY_Build  \
# 0  Available. Released 2018, July       544.00        NaN
# 1                    Discontinued       260.00        NaN
# 2                    Discontinued       169.00        NaN
# 3                    Discontinued       126.00        NaN
# 4                    Discontinued       175.16        NaN
#
#                                                                BODY_SIM  \
# 0                                                                    No
# 1                                         Dual SIM (Micro-SIM/Nano-SIM)
# 2  Single SIM (Micro-SIM) or Hybrid Dual SIM (Micro-SIM, dual stand-by)
# 3         Single SIM (Micro-SIM) or Dual SIM (Micro-SIM, dual stand-by)
# 4                                                                    No
#
#   DISPLAY_Type                                          DISPLAY_Size  \
# 0      IPS LCD   9.7 inches, 291.4 cm2 (~71.0% screen-to-body ratio)
# 1      IPS LCD   7.0 inches, 135.1 cm2 (~69.8% screen-to-body ratio)
# 2      IPS LCD    5.5 inches, 83.4 cm2 (~71.7% screen-to-body ratio)
# 3      IPS LCD    5.0 inches, 68.9 cm2 (~65.3% screen-to-body ratio)
# 4      IPS LCD  10.1 inches, 295.8 cm2 (~68.4% screen-to-body ratio)
#
#                                    DISPLAY_Resolution DISPLAY_Protection  \
# 0    1536 x 2048 pixels, 4:3 ratio (~264 ppi density)                NaN
# 1    720 x 1280 pixels, 16:9 ratio (~210 ppi density)                NaN
# 2   1080 x 1920 pixels, 16:9 ratio (~401 ppi density)                NaN
# 3    720 x 1280 pixels, 16:9 ratio (~294 ppi density)                NaN
# 4  1920 x 1200 pixels, 16:10 ratio (~224 ppi density)                NaN
#
#                  PLATFORM_OS         PLATFORM_Chipset  \
# 0                  Chrome OS          Rockchip RK3399
# 1  Android 6.0 (Marshmallow)          Mediatek MT8735
# 2  Android 6.0 (Marshmallow)  Mediatek MT6753 (28 nm)
# 3  Android 6.0 (Marshmallow)  Mediatek MT6737 (28 nm)
# 4  Android 6.0 (Marshmallow)         Mediatek MT8163A
#
#                                 PLATFORM_CPU   PLATFORM_GPU  \
# 0  Hexa-core (4x Cortex-A53 & 2x Cortex-A72)            NaN
# 1               Quad-core 1.3 GHz Cortex-A53   Mali-T720MP2
# 2               Octa-core 1.3 GHz Cortex-A53   Mali-T720MP3
# 3              Quad-core 1.25 GHz Cortex-A53   Mali-T720MP2
# 4               Quad-core 1.3 GHz Cortex-A53  Mali-T720 MP2
#
#                    MEMORY_Card_slot                           MEMORY_Internal  \
# 0        microSDXC (dedicated slot)                              32GB 4GB RAM
# 1        microSDXC (dedicated slot)                16GB 2GB RAM, 32GB 2GB RAM
# 2  microSDXC (uses shared SIM slot)                              32GB 3GB RAM
# 3                         microSDXC                               8GB 1GB RAM
# 4        microSDXC (dedicated slot)  16GB 2GB RAM, 32GB 2GB RAM, 64GB 2GB RAM
#
#    MAIN_CAM_1_Module       MAIN_CAM_1_Features MAIN_CAM_1_Video  \
# 0                  1                       NaN             720p
# 1                  1             HDR, panorama      1080p@30fps
# 2                  1  LED flash, HDR, panorama      1080p@30fps
# 3                  1  LED flash, HDR, panorama              Yes
# 4                  1                       NaN      1080p@30fps
#
#    SELFIE_CAM_2_Module SELFIE_CAM_2_Features SELFIE_CAM_2_Video  \
# 0                    1                   NaN                NaN
# 1                    1                   NaN               720p
# 2                    1                   NaN                NaN
# 3                    1                   NaN                NaN
# 4                    1                   NaN                NaN
#
#                         SOUND_Loudspeaker SOUND_35mm_jack  \
# 0               Yes, with stereo speakers             Yes
# 1                                     Yes             Yes
# 2                                     Yes             Yes
# 3                                     Yes             Yes
# 4  Yes, with stereo speakers (4 speakers)             Yes
#
#                                        COMMS_WLAN COMMS_Bluetooth  \
# 0  Wi-Fi 802.11 b/g/n/ac, dual-band, Wi-Fi Direct   4.1, A2DP, LE
# 1              Wi-Fi 802.11 a/b/g/n, Wi-Fi Direct       4.0, A2DP
# 2                Wi-Fi 802.11 b/g/n, Wi-Fi Direct       4.0, A2DP
# 3                              Wi-Fi 802.11 b/g/n       4.0, A2DP
# 4              Wi-Fi 802.11 a/b/g/n/ac, dual-band       4.0, A2DP
#
#       COMMS_GPS COMMS_NFC COMMS_Radio       COMMS_USB  FEATURES_Sensors  \
# 0           NaN        No          No  USB Type-C 3.1            201.37
# 1  GPS, GLONASS        No    FM radio    microUSB 2.0            230.63
# 2           GPS        No    FM radio    microUSB 2.0            298.73
# 3           GPS        No    FM radio    microUSB 2.0            230.63
# 4           NaN        No          No    microUSB 2.0            201.37
#
#                                 BATTERY_Type BATTERY_Stand_by  \
# 0      Li-Po 4500 mAh, non-removable (34 Wh)              NaN
# 1  Li-Ion 3400 mAh, non-removable (12.92 Wh)              NaN
# 2              Li-Po 4080 mAh, non-removable              NaN
# 3                 Li-Ion 2000 mAh, removable              NaN
# 4             Li-Ion 6100 mAh, non-removable              NaN
#
#         BATTERY_Talk_time BATTERY_Music_play   MISC_Colors MISC_SAR  \
# 0  Up to 9 h (multimedia)                NaN   Black, Blue      NaN
# 1  Up to 9 h (multimedia)                NaN         Black      NaN
# 2                     NaN                NaN  Black, White      NaN
# 3                     NaN                NaN  Black, White      NaN
# 4                     NaN                NaN         Black      NaN
#
#   MISC_SAR_EU MISC_Models  MISC_Price_Euro  BODY_Length  BODY_Width  \
# 0         NaN         NaN           330.23       238.30      172.20
# 1         NaN         NaN           172.48       191.70      101.00
# 2         NaN         NaN           252.01       153.80       75.60
# 3         NaN         NaN           126.63       145.50       72.50
# 4         NaN         NaN           236.09       259.00      167.00
#
#    BODY_Thickness  Mean_Price_Euro
# 0            9.90           201.37
# 1            9.40           230.63
# 2            8.50           298.73
# 3            8.50           230.63
# 4            8.90           201.37

# %% [markdown]
# matrix -> binary -> hash %120 (stupid af) bỏ

# %%
# def sensors_to_number(sensors, all_sensors):
#     if isinstance(sensors, str):
#         sensors_list = sensors.split(', ')
#     else:
#         sensors_list = []
#     binary_vector = [1 if sensor in sensors_list else 0 for sensor in all_sensors]
#     binary = ''.join(map(str, binary_vector))
#     binary =  int(binary, 2)
#     binary = binary % 120
#     return binary

# df['matrix_sensors'] = df['FEATURES_Sensors'].apply(lambda x: sensors_to_number(x, sensors))
# df['matrix_sensors'].head()

# %% [markdown]
# ## testing w/ models

# %%
#print corr of each feature with price
corr = df.corr()
corr.style.background_gradient(cmap='bwr')
# Out:
# <style type="text/css">
# #T_154b1_row0_col0, #T_154b1_row1_col1, #T_154b1_row2_col2, #T_154b1_row3_col3, #T_154b1_row4_col4, #T_154b1_row5_col5, #T_154b1_row6_col6, #T_154b1_row7_col7, #T_154b1_row8_col8, #T_154b1_row9_col9, #T_154b1_row10_col10, #T_154b1_row11_col11, #T_154b1_row12_col12, #T_154b1_row12_col17, #T_154b1_row13_col13, #T_154b1_row14_col14, #T_154b1_row15_col15, #T_154b1_row16_col16, #T_154b1_row17_col12, #T_154b1_row17_col17 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_154b1_row0_col1, #T_154b1_row3_col15, #T_154b1_row6_col2 {
#   background-color: #d8d8ff;
#   color: #000000;
# }
# #T_154b1_row0_col2 {
#   background-color: #c2c2ff;
#   color: #000000;
# }
# #T_154b1_row0_col3, #T_154b1_row0_col16, #T_154b1_row6_col4, #T_154b1_row7_col4, #T_154b1_row7_col10, #T_154b1_row10_col1, #T_154b1_row10_col9 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_154b1_row0_col4 {
#   background-color: #b2b2ff;
#   color: #000000;
# }
# #T_154b1_row0_col5, #T_154b1_row6_col13, #T_154b1_row7_col13 {
#   background-color: #6868ff;
#   color: #f1f1f1;
# }
# #T_154b1_row0_col6, #T_154b1_row15_col3 {
#   background-color: #babaff;
#   color: #000000;
# }
# #T_154b1_row0_col7, #T_154b1_row5_col15, #T_154b1_row8_col13, #T_154b1_row12_col13, #T_154b1_row15_col10, #T_154b1_row17_col13 {
#   background-color: #b4b4ff;
#   color: #000000;
# }
# #T_154b1_row0_col8, #T_154b1_row2_col4 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_154b1_row0_col9 {
#   background-color: #8484ff;
#   color: #f1f1f1;
# }
# #T_154b1_row0_col10 {
#   background-color: #3838ff;
#   color: #f1f1f1;
# }
# #T_154b1_row0_col11 {
#   background-color: #d4d4ff;
#   color: #000000;
# }
# #T_154b1_row0_col12, #T_154b1_row0_col17, #T_154b1_row1_col15, #T_154b1_row2_col15, #T_154b1_row10_col6, #T_154b1_row10_col12, #T_154b1_row10_col17 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_154b1_row0_col13 {
#   background-color: #ff9494;
#   color: #000000;
# }
# #T_154b1_row0_col14, #T_154b1_row5_col7, #T_154b1_row6_col10 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_154b1_row0_col15, #T_154b1_row15_col4 {
#   background-color: #aaaaff;
#   color: #000000;
# }
# #T_154b1_row1_col0, #T_154b1_row9_col5, #T_154b1_row11_col13, #T_154b1_row14_col13 {
#   background-color: #7878ff;
#   color: #f1f1f1;
# }
# #T_154b1_row1_col2, #T_154b1_row11_col1 {
#   background-color: #ffcccc;
#   color: #000000;
# }
# #T_154b1_row1_col3, #T_154b1_row8_col3, #T_154b1_row13_col0 {
#   background-color: #ff9c9c;
#   color: #000000;
# }
# #T_154b1_row1_col4 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_154b1_row1_col5, #T_154b1_row5_col12, #T_154b1_row5_col17 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_154b1_row1_col6 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_154b1_row1_col7 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_154b1_row1_col8 {
#   background-color: #ff5e5e;
#   color: #f1f1f1;
# }
# #T_154b1_row1_col9, #T_154b1_row7_col8, #T_154b1_row14_col3 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_154b1_row1_col10, #T_154b1_row3_col0, #T_154b1_row3_col10, #T_154b1_row15_col13 {
#   background-color: #7c7cff;
#   color: #f1f1f1;
# }
# #T_154b1_row1_col11 {
#   background-color: #ffb4b4;
#   color: #000000;
# }
# #T_154b1_row1_col12, #T_154b1_row1_col17 {
#   background-color: #ff7474;
#   color: #f1f1f1;
# }
# #T_154b1_row1_col13, #T_154b1_row9_col3, #T_154b1_row13_col7 {
#   background-color: #c0c0ff;
#   color: #000000;
# }
# #T_154b1_row1_col14, #T_154b1_row4_col3 {
#   background-color: #ffc8c8;
#   color: #000000;
# }
# #T_154b1_row1_col16 {
#   background-color: #4c4cff;
#   color: #f1f1f1;
# }
# #T_154b1_row2_col0, #T_154b1_row5_col10 {
#   background-color: #7676ff;
#   color: #f1f1f1;
# }
# #T_154b1_row2_col1 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_154b1_row2_col3, #T_154b1_row4_col14, #T_154b1_row11_col9, #T_154b1_row11_col10 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_154b1_row2_col5, #T_154b1_row5_col16, #T_154b1_row7_col9, #T_154b1_row12_col10, #T_154b1_row13_col5, #T_154b1_row17_col10 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_154b1_row2_col6, #T_154b1_row8_col6, #T_154b1_row15_col2 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_154b1_row2_col7, #T_154b1_row5_col14, #T_154b1_row12_col9, #T_154b1_row17_col9 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_154b1_row2_col8, #T_154b1_row6_col1 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_154b1_row2_col9, #T_154b1_row4_col2, #T_154b1_row8_col15 {
#   background-color: #d6d6ff;
#   color: #000000;
# }
# #T_154b1_row2_col10 {
#   background-color: #8a8aff;
#   color: #f1f1f1;
# }
# #T_154b1_row2_col11, #T_154b1_row5_col4, #T_154b1_row12_col3, #T_154b1_row17_col3 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_154b1_row2_col12, #T_154b1_row2_col17 {
#   background-color: #ff9e9e;
#   color: #000000;
# }
# #T_154b1_row2_col13, #T_154b1_row9_col16 {
#   background-color: #8282ff;
#   color: #f1f1f1;
# }
# #T_154b1_row2_col14, #T_154b1_row6_col14 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_154b1_row2_col16, #T_154b1_row10_col5 {
#   background-color: #6666ff;
#   color: #f1f1f1;
# }
# #T_154b1_row3_col1 {
#   background-color: #ff8c8c;
#   color: #000000;
# }
# #T_154b1_row3_col2 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_154b1_row3_col4, #T_154b1_row9_col11 {
#   background-color: #ffcaca;
#   color: #000000;
# }
# #T_154b1_row3_col5, #T_154b1_row9_col2, #T_154b1_row10_col7 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_154b1_row3_col6, #T_154b1_row14_col2 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_154b1_row3_col7, #T_154b1_row13_col4 {
#   background-color: #f0f0ff;
#   color: #000000;
# }
# #T_154b1_row3_col8, #T_154b1_row11_col6 {
#   background-color: #ff9292;
#   color: #000000;
# }
# #T_154b1_row3_col9 {
#   background-color: #b8b8ff;
#   color: #000000;
# }
# #T_154b1_row3_col11, #T_154b1_row8_col5, #T_154b1_row13_col12, #T_154b1_row13_col17 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_154b1_row3_col12, #T_154b1_row3_col17, #T_154b1_row12_col7, #T_154b1_row17_col7 {
#   background-color: #ffa0a0;
#   color: #000000;
# }
# #T_154b1_row3_col13, #T_154b1_row13_col2, #T_154b1_row14_col4 {
#   background-color: #bebeff;
#   color: #000000;
# }
# #T_154b1_row3_col14, #T_154b1_row4_col11, #T_154b1_row7_col1 {
#   background-color: #fff0f0;
#   color: #000000;
# }
# #T_154b1_row3_col16, #T_154b1_row4_col0, #T_154b1_row10_col4 {
#   background-color: #7a7aff;
#   color: #f1f1f1;
# }
# #T_154b1_row4_col1 {
#   background-color: #ffc2c2;
#   color: #000000;
# }
# #T_154b1_row4_col5 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_154b1_row4_col6 {
#   background-color: #e4e4ff;
#   color: #000000;
# }
# #T_154b1_row4_col7, #T_154b1_row10_col15, #T_154b1_row13_col14, #T_154b1_row15_col6 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_154b1_row4_col8, #T_154b1_row5_col8, #T_154b1_row15_col12, #T_154b1_row15_col17 {
#   background-color: #ffbebe;
#   color: #000000;
# }
# #T_154b1_row4_col9 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_154b1_row4_col10 {
#   background-color: #6a6aff;
#   color: #f1f1f1;
# }
# #T_154b1_row4_col12, #T_154b1_row4_col17 {
#   background-color: #ffbaba;
#   color: #000000;
# }
# #T_154b1_row4_col13, #T_154b1_row6_col15, #T_154b1_row7_col2, #T_154b1_row9_col6 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_154b1_row4_col15, #T_154b1_row5_col2, #T_154b1_row7_col3, #T_154b1_row9_col7 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_154b1_row4_col16, #T_154b1_row6_col5, #T_154b1_row7_col5 {
#   background-color: #7e7eff;
#   color: #f1f1f1;
# }
# #T_154b1_row5_col0, #T_154b1_row6_col0, #T_154b1_row7_col16, #T_154b1_row15_col0 {
#   background-color: #4646ff;
#   color: #f1f1f1;
# }
# #T_154b1_row5_col1, #T_154b1_row15_col11 {
#   background-color: #ffb8b8;
#   color: #000000;
# }
# #T_154b1_row5_col3, #T_154b1_row9_col1, #T_154b1_row11_col2, #T_154b1_row11_col8, #T_154b1_row13_col1, #T_154b1_row15_col1 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_154b1_row5_col6, #T_154b1_row15_col8 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_154b1_row5_col9 {
#   background-color: #9292ff;
#   color: #f1f1f1;
# }
# #T_154b1_row5_col11 {
#   background-color: #f6f6ff;
#   color: #000000;
# }

# %% [markdown]
# NETWORK_GPRS + NETWORK_EDGE khá cùi pắp

# %% [markdown]
# Nên chia lại test và train ra 1 chỗ riêng để evaluate tốt hơn df_na (vì khi chia lại bằng hàm thì có khả năng nó eval bằng chính cái nó tự sinh <br>
# dễ gây overfitting)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
regressors = config['regressors']
#removed regressors are those not in regressors 
removed_regressors = [est[0] for est in all_estimators() if (est[0] not in regressors)]

regressor_list = [
    est
    for est in all_estimators()
    if (issubclass(est[1], RegressorMixin) and (est[0] not in removed_regressors))
]

# %% [markdown]
# #### Train ko cần NaN (ko fill in target)

# %%
config['variables']
# Out:
# ['Brand',
#  'NETWORK_2G_bands',
#  'NETWORK_3G_bands',
#  'NETWORK_4G_bands',
#  'NETWORK_5G_bands',
#  'NETWORK_Speed',
#  'NETWORK_Technology',
#  'BODY_Length',
#  'BODY_Width',
#  'BODY_Thickness',
#  'BODY_Weight',
#  'FEATURES_Sensors']

# %%
X = df[config['variables']]
y = df['MISC_Price_Euro']
X.head()
# Out:
#    Brand  NETWORK_2G_bands  NETWORK_3G_bands  NETWORK_4G_bands  \
# 0 175.03            227.52            227.52            227.52
# 1 175.03            227.52            227.52            227.52
# 2 175.03            227.52            227.52            227.52
# 3 175.03            239.76            239.76            239.76
# 4 175.03            278.87            278.87            278.87
#
#    NETWORK_5G_bands  NETWORK_Speed  NETWORK_Technology  BODY_Length  \
# 0            227.52         227.52              227.52       238.30
# 1            278.87         227.52              227.52       191.70
# 2            243.41         227.52              200.00       153.80
# 3            245.56         227.52              217.34       145.50
# 4            221.77         278.87              278.87       259.00
#
#    BODY_Width  BODY_Thickness  BODY_Weight  FEATURES_Sensors
# 0      172.20            9.90       544.00            201.37
# 1      101.00            9.40       260.00            230.63
# 2       75.60            8.50       169.00            298.73
# 3       72.50            8.50       126.00            230.63
# 4      167.00            8.90       175.16            201.37

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X,y)
X_scaled = pd.DataFrame(X, columns=config['variables'])
X_scaled.head()
# Out:
#    Brand  NETWORK_2G_bands  NETWORK_3G_bands  NETWORK_4G_bands  \
# 0  -0.23              0.05             -0.01              0.21
# 1  -0.23              0.05             -0.01              0.21
# 2  -0.23              0.05             -0.01              0.21
# 3  -0.23              0.22              0.10              0.33
# 4  -0.23              0.77              0.45              0.72
#
#    NETWORK_5G_bands  NETWORK_Speed  NETWORK_Technology  BODY_Length  \
# 0              0.19          -0.04               -0.04         2.50
# 1              0.98          -0.04               -0.04         1.27
# 2              0.44          -0.04               -0.24         0.27
# 3              0.47          -0.04               -0.11         0.05
# 4              0.10           0.41                0.34         3.05
#
#    BODY_Width  BODY_Thickness  BODY_Weight  FEATURES_Sensors
# 0        3.68           -0.22         3.51             -0.20
# 1        1.05           -0.36         0.81              0.04
# 2        0.11           -0.63        -0.06              0.60
# 3       -0.00           -0.63        -0.47              0.04
# 4        3.49           -0.51         0.00             -0.20

# %%
y = scaler.fit_transform(np.array(y).reshape(-1, 1))
y_scaled = pd.DataFrame(y, columns=['MISC_Price_Euro'])

# %%
df_scaled = pd.concat([X_scaled, y_scaled], axis=1)

# %% [markdown]
# chia `test` và `train` ra 2 chỗ riêng, đảm bảo khi eval thì ko bị overfitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=0)
#remove test set from df_scaled
df_scaled = df_scaled.drop(X_test.index)
df_scaled.shape
# Out:
# (5906, 13)

# %%
X_test.shape
# Out:
# (2532, 12)

# %%
y_train = y_train.squeeze()
y_test = y_test.squeeze()

# %%
def lazy_eval(X_train, y_train, X_test, y_test):
    reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None,predictions=False, regressors = regressor_list)
    models, predictions = reg.fit(X_train, X_test, y_train, y_test)
    return models, predictions

# %%
models, predictions = lazy_eval(X_train, y_train, X_test, y_test)
# Out:
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 6/6 [00:21<00:00,  3.53s/it]

# %%
models
# Out:
#                            Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                0.54       0.54  0.63        3.06
# ExtraTreesRegressor                      0.52       0.52  0.64        4.05
# RandomForestRegressor                    0.49       0.50  0.66       13.84
# LinearRegression                         0.37       0.37  0.73        0.04
# SGDRegressor                             0.37       0.37  0.74        0.04
# KNeighborsRegressor                      0.35       0.35  0.75        0.14

# %%
n = len(config['regressors'])
ncols = 2
nrows = int(np.ceil(n / ncols))

fig, axs = plt.subplots(nrows, ncols, figsize=(16, 10*nrows))

# Flatten the 2D array to 1D for easier looping
axs = axs.flatten()

for ax, Regressor in zip(axs, config['regressors']):
    # Create an instance of the regressor
    model = eval(Regressor)()  # Convert the string to an actual regressor object
    
    # Fit the model with the training data
    model.fit(X_train, y_train)
    
    # Create the ResidualsPlot with the model
    visualizer = ResidualsPlot(model, ax=ax)
    
    # Fit the visualizer with the training data
    visualizer.fit(X_train, y_train)
    
    # Score the visualizer with the test data
    visualizer.score(X_test, y_test)
    
    # Add a title to the plot
    visualizer.set_title(f'Residuals Plot for {Regressor}')
    
    # Add a custom legend
    ax.legend(["Training", "Test"], loc='upper right')

# Remove empty subplots
if n % ncols != 0:
    for ax in axs[n:]:
        fig.delaxes(ax)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### re-train and testing with lazy predict (sau khi fill-in target và evaluate lại) `bỏ`

# %%
# def target_fill_with_retrain(df, model, variables, target):
#     X = df_scaled[variables]
#     y = df_scaled[target]
#     model.fit(X, y)
#     X_na = df_na[variables]
#     y_na = model.predict(X_na)
#     df_na[target] = y_na
#     df = df.append(df_na)
#     return df

# model = ExtraTreesRegressor()
# df = target_fill_with_retrain(df_scaled, model, config['fillna_retrain_variables'], config['target'])
# df.shape

# %%
# models_retrain, predictions_retrain = lazy_eval(df[config['variables']], df['MISC_Price_Euro'], X_test, y_test)

# %% [markdown]
# **Nhận xét sau khi fillin = regressor**:
# - `một vài regressor không hoạt động` lasso, elasticnet, ridge thì chắc do implement (bỏ khỏi regressors), sgd nhìn chung do outlier, nhìn thì thấp nhưng mà một vài outlier khiến mean tụt xuống (chọn lại features)
# - `một vài regressor hoạt động tốt` nhưng mà `mean` của nó thấp hơn so với `mean` của `train` (có thể do `train` có nhiều outlier hơn `test`)
# - `đọc lại plot thấy cần edit lại nhận xét hmm`

# %%
# df_output = df['Brand', 'NETWORK_Technology	NETWORK_2G_bands	NETWORK_3G_bands	NETWORK_4G_bands	NETWORK_5G_bands	NETWORK_GPRS	NETWORK_EDGE''NETWORK_Speed	LAUNCH_Announced' BODY_Weight' 'BODY_Length	BODY_Width	BODY_Thickness'  'MISC_Price_Euro'] ]
df_output = df[['Brand' ,'NETWORK_Technology', 'NETWORK_2G_bands', 'NETWORK_3G_bands', 'NETWORK_4G_bands', 'NETWORK_5G_bands', 'NETWORK_GPRS', 'NETWORK_EDGE', 'NETWORK_Speed', 'LAUNCH_Announced', 'BODY_Weight', 'BODY_Length', 'BODY_Width' ,'BODY_Weight', 'BODY_Thickness','FEATURES_Sensors']]
df_output.head()
# Out:
#    Brand  NETWORK_Technology  NETWORK_2G_bands  NETWORK_3G_bands  \
# 0 175.03              227.52            227.52            227.52
# 1 175.03              227.52            227.52            227.52
# 2 175.03              200.00            227.52            227.52
# 3 175.03              217.34            239.76            239.76
# 4 175.03              278.87            278.87            278.87
#
#    NETWORK_4G_bands  NETWORK_5G_bands  NETWORK_GPRS  NETWORK_EDGE  \
# 0            227.52            227.52            10            13
# 1            227.52            278.87            21            22
# 2            227.52            243.41            20            19
# 3            239.76            245.56            20            19
# 4            278.87            221.77            10            13
#
#    NETWORK_Speed                       LAUNCH_Announced  BODY_Weight  \
# 0         227.52                            2018, March       544.00
# 1         227.52   2016, August. Released 2016, October       260.00
# 2         227.52  2016, August. Released 2016, December       169.00
# 3         227.52  2016, August. Released 2016, December       126.00
# 4         278.87       2016, April. Released 2016, June       175.16
#
#    BODY_Length  BODY_Width  BODY_Weight  BODY_Thickness  FEATURES_Sensors
# 0       238.30      172.20       544.00            9.90            201.37
# 1       191.70      101.00       260.00            9.40            230.63
# 2       153.80       75.60       169.00            8.50            298.73
# 3       145.50       72.50       126.00            8.50            230.63
# 4       259.00      167.00       175.16            8.90            201.37

# %%
def LAUNCH_Announced_preprocessed(df):
    df['LAUNCH_Announced'] = df['LAUNCH_Announced'].replace('Not announced yet', np.nan)
    df['LAUNCH_Announced'] = df['LAUNCH_Announced'].str.extract('(\d{4})')
    return df

# %%
df_output = LAUNCH_Announced_preprocessed(df_output)
# df_output_na = LAUNCH_Announced_preprocessed(df_output_na)

# %%
df_output.to_csv(os.path.join(config['SavePath'], config['files'] + "_output.csv"), index=False)

# %%
# merged_df = pd.concat([df_output, df_output_na])
# #sort by index
# merged_df = merged_df.sort_index()
# merged_df.head(10)

# %%
# df['MISC_Price_Euro'].head(10)

# %%
# merged_df = merged_df.join(df['MISC_Price_Euro'])

# %%
# merged_df.to_csv('lam_output.csv', index=False)

# %%
# merged_df.shape
